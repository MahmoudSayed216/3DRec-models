# %%
import torch
import timm
import matplotlib.pyplot as plt

# %%
model = timm.create_model("tf_efficientnetv2_m_in21k", pretrained=True, features_only = True)
# Out:
# /home/mahmoud-sayed/miniconda3/envs/p2v9/lib/python3.9/site-packages/timm/models/_factory.py:117: UserWarning: Mapping deprecated model name tf_efficientnetv2_m_in21k to current tf_efficientnetv2_m.in21k.
#   model = create_fn(
# model.safetensors:   0%|          | 0.00/325M [00:00<?, ?B/s]
# Unexpected keys (bn2.bias, bn2.num_batches_tracked, bn2.running_mean, bn2.running_var, bn2.weight, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.

# %%
model
# Out:
# EfficientNetFeatures(
#   (conv_stem): Conv2dSame(3, 24, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn1): BatchNormAct2d(
#     24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (aa): Identity()
#         (drop_path): Identity()
#       )
#       (1): ConvBnAct(
#         (conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
# ...

# %%
model.blocks[0].parameters()
# Out:
# <generator object Module.parameters at 0x70a245ff5dd0>

# %%
output = model(torch.rand((1, 3, 224, 224)))

# %%
print(output[0].shape)
print(output[1].shape)
print(output[2].shape)
print(output[3].shape)
print(output[4].shape)
# Out:
# torch.Size([1, 24, 112, 112])
# torch.Size([1, 48, 56, 56])
# torch.Size([1, 80, 28, 28])
# torch.Size([1, 176, 14, 14])
# torch.Size([1, 512, 7, 7])

# %%
model = timm.create_model('convnext_base')

# %%
output = model(torch.rand((1, 3, 224, 224)))

# %%
output.shape
# Out:
# torch.Size([1, 1000])

# %%
print(torch.argmax(output))
# Out:
# tensor(988)

# %%
print(output[0][-15:-1])
# Out:
# tensor([ 0.3727,  0.1612, -0.0457,  2.0721, -0.1343,  0.1803,  0.1496, -0.0119,
#          0.9179,  0.1174,  0.4881, -1.2477,  0.2488, -0.6056],
#        grad_fn=<SliceBackward0>)
